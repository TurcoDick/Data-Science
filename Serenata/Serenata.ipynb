# %%
from serenata_toolbox.datasets import Datasets

# %%
datasets = Datasets('data/')

# %%
datasets.downloader.download('2017-07-04-reimbursements.xz')

# %%
import pandas as pd

# %%
 df = pd.read_csv('data/2017-07-04-reimbursements.xz')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[:5]
# Out:
#    year  applicant_id  document_id  reimbursement_value_total  \
# 0  2009          1001      1564212                        0.0
# 1  2009          1001      1564223                        0.0
# 2  2009          1001      1568039                        0.0
# 3  2009          1001      1568056                        0.0
# 4  2009          1001      1568098                        0.0
#
#    total_net_value reimbursement_numbers congressperson_name  \
# 0           130.00                  2888    DILCEU SPERAFICO
# 1           135.00                  2888    DILCEU SPERAFICO
# 2          1000.00                  2893    DILCEU SPERAFICO
# 3           170.00                  2894    DILCEU SPERAFICO
# 4           100.11                  2894    DILCEU SPERAFICO
#
#    congressperson_id  congressperson_document    term         ...           \
# 0            73768.0                    444.0  2015.0         ...
# 1            73768.0                    444.0  2015.0         ...
# ...

# %%
df.head()
# Out:
#    year  applicant_id  document_id  reimbursement_value_total  \
# 0  2009          1001      1564212                        0.0
# 1  2009          1001      1564223                        0.0
# 2  2009          1001      1568039                        0.0
# 3  2009          1001      1568056                        0.0
# 4  2009          1001      1568098                        0.0
#
#    total_net_value reimbursement_numbers congressperson_name  \
# 0           130.00                  2888    DILCEU SPERAFICO
# 1           135.00                  2888    DILCEU SPERAFICO
# 2          1000.00                  2893    DILCEU SPERAFICO
# 3           170.00                  2894    DILCEU SPERAFICO
# 4           100.11                  2894    DILCEU SPERAFICO
#
#    congressperson_id  congressperson_document    term         ...           \
# 0            73768.0                    444.0  2015.0         ...
# 1            73768.0                    444.0  2015.0         ...
# ...

# %%
df.shape
# Out:
# (1619213, 31)

# %%
df.columns
# Out:
# Index(['year', 'applicant_id', 'document_id', 'reimbursement_value_total',
#        'total_net_value', 'reimbursement_numbers', 'congressperson_name',
#        'congressperson_id', 'congressperson_document', 'term', 'state',
#        'party', 'term_id', 'subquota_number', 'subquota_description',
#        'subquota_group_id', 'subquota_group_description', 'supplier',
#        'cnpj_cpf', 'document_number', 'document_type', 'issue_date',
#        'document_value', 'remark_value', 'net_values', 'month', 'installment',
#        'passenger', 'leg_of_the_trip', 'batch_number', 'reimbursement_values'],
#       dtype='object')

# %%
df.iloc[3]
# Out:
# year                                                         2009
# applicant_id                                                 1001
# document_id                                               1568056
# reimbursement_value_total                                       0
# total_net_value                                               170
# reimbursement_numbers                                        2894
# congressperson_name                              DILCEU SPERAFICO
# congressperson_id                                           73768
# congressperson_document                                       444
# term                                                         2015
# state                                                          PR
# party                                                          PP
# term_id                                                        55
# subquota_number                                                 3
# ...

# %%
import numpy as np

# %%
df = pd.read_csv('data/2017-07-04-reimbursements.xz', dtype={'cnpj_cpf' : np.str})
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.iloc[3]
# Out:
# year                                                         2009
# applicant_id                                                 1001
# document_id                                               1568056
# reimbursement_value_total                                       0
# total_net_value                                               170
# reimbursement_numbers                                        2894
# congressperson_name                              DILCEU SPERAFICO
# congressperson_id                                           73768
# congressperson_document                                       444
# term                                                         2015
# state                                                          PR
# party                                                          PP
# term_id                                                        55
# subquota_number                                                 3
# ...

# %%
df['subquota_description']
# Out:
# 0                                       Fuels and lubricants
# 1                               Locomotion, meal and lodging
# 2          Maintenance of office supporting parliamentary...
# 3                                       Fuels and lubricants
# 4                                       Fuels and lubricants
# 5          Software purchase or renting; Postal services;...
# 6                               Locomotion, meal and lodging
# 7                                       Fuels and lubricants
# 8                                       Fuels and lubricants
# 9                                       Fuels and lubricants
# 10                                      Fuels and lubricants
# 11                                      Fuels and lubricants
# 12                                      Fuels and lubricants
# 13                                      Fuels and lubricants
# 14                                      Fuels and lubricants
# ...

# %%
df['subquota_description'].unique()
# Out:
# array(['Fuels and lubricants', 'Locomotion, meal and lodging',
#        'Maintenance of office supporting parliamentary activity',
#        'Software purchase or renting; Postal services; Subscriptions',
#        'Publicity of parliamentary activity',
#        'Purchase of office supplies',
#        'Security service provided by specialized company',
#        'Flight tickets', 'Congressperson meal', 'Telecommunication',
#        'Lodging, except for congressperson from Distrito Federal',
#        'Automotive vehicle renting or watercraft charter',
#        'Postal services', 'Consultancy, research and technical work',
#        'Publication subscriptions', 'Taxi, toll and parking',
#        'Automotive vehicle renting or charter',
#        'Terrestrial, maritime and fluvial tickets',
#        'Aircraft renting or charter of aircraft',
#        'Watercraft renting or charter',
#        'Participation in course, talk or similar event'], dtype=object)

# %%
meals = df.query('subquota_description == "Congressperson meal" ')

# %%
meals
# Out:
#          year  applicant_id  document_id  reimbursement_value_total  \
# 159      2009          1001      1627199                        0.0
# 196      2009          1001      1635276                        0.0
# 380      2009          1001      1709015                        0.0
# 407      2009          1001      1722100                        0.0
# 414      2009          1001      1726433                        0.0
# 758      2009          1003      1617069                        0.0
# 774      2009          1003      1621808                        0.0
# 802      2009          1003      1629189                        0.0
# 818      2009          1003      1635062                        0.0
# 820      2009          1003      1635072                        0.0
# 822      2009          1003      1635080                        0.0
# 832      2009          1003      1635139                        0.0
# 833      2009          1003      1635146                        0.0
# ...

# %%
len(meals)
# Out:
# 201600

# %%
df.iloc[42]
# Out:
# year                                          2009
# applicant_id                                  1001
# document_id                                1581821
# reimbursement_value_total                        0
# total_net_value                                125
# reimbursement_numbers                         2909
# congressperson_name               DILCEU SPERAFICO
# congressperson_id                            73768
# congressperson_document                        444
# term                                          2015
# state                                           PR
# party                                           PP
# term_id                                         55
# subquota_number                                  3
# subquota_description          Fuels and lubricants
# subquota_group_id                                1
# subquota_group_description    Veículos Automotores
# supplier                       AUTO POSTO IMPERIAL
# ...

# %%
meals['total_net_value'].describe()
# Out:
# count    201600.000000
# mean         65.687914
# std          98.034144
# min           0.010000
# 25%          25.000000
# 50%          46.080000
# 75%          85.000000
# max        6205.000000
# Name: total_net_value, dtype: float64

# %%
meals.query('total_net_value < 5000')
# Out:
#          year  applicant_id  document_id  reimbursement_value_total  \
# 159      2009          1001      1627199                        0.0
# 196      2009          1001      1635276                        0.0
# 380      2009          1001      1709015                        0.0
# 407      2009          1001      1722100                        0.0
# 414      2009          1001      1726433                        0.0
# 758      2009          1003      1617069                        0.0
# 774      2009          1003      1621808                        0.0
# 802      2009          1003      1629189                        0.0
# 818      2009          1003      1635062                        0.0
# 820      2009          1003      1635072                        0.0
# 822      2009          1003      1635080                        0.0
# 832      2009          1003      1635139                        0.0
# 833      2009          1003      1635146                        0.0
# ...

# %%
meals = meals.dropna?

# %%
meals = meals.dropna

# %%
meals = meals.query('congressperson_id == congressperson_id')

# %%
meals.query('total_net_value < 5000')
# Out:
#          year  applicant_id  document_id  reimbursement_value_total  \
# 159      2009          1001      1627199                        0.0
# 196      2009          1001      1635276                        0.0
# 380      2009          1001      1709015                        0.0
# 407      2009          1001      1722100                        0.0
# 414      2009          1001      1726433                        0.0
# 758      2009          1003      1617069                        0.0
# 774      2009          1003      1621808                        0.0
# 802      2009          1003      1629189                        0.0
# 818      2009          1003      1635062                        0.0
# 820      2009          1003      1635072                        0.0
# 822      2009          1003      1635080                        0.0
# 832      2009          1003      1635139                        0.0
# 833      2009          1003      1635146                        0.0
# ...

# %%
meals.groupby?

# %%
def group_restaurants(df):
    return pd.Series({
        'cnpj': df.iloc[0]['cnpj_cpf'],
        'mean': mean,
        'std' : std,
        'limit' : mean + (2 * std),
        'count' : len(df)
    })
limits = meals.groupby('cnpj_cpf').apply(group_restaurants).sort_values('count', ascending=False).reset_index()
limits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-857378806f8a> in <module>()
#       7         'count' : len(df)
#       8     })
# ----> 9 limits = meals.groupby('cnpj_cpf').apply(group_restaurants).sort_values('count', ascending=False).reset_index()
#      10 limits
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %%
final = meals.merge(limits, left_on='cnpj_cpf', rigth_on='cnpj')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-5d9703446851> in <module>()
# ----> 1 final = meals.merge(limits, left_on='cnpj_cpf', rigth_on='cnpj')
#
# NameError: name 'limits' is not defined
