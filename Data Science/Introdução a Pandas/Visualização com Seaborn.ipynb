# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1,10,100)

# %%
plt.plot(x, np.sin(x), 'b--')
plt.plot(x, np.cos(x), 'r--')
plt.show()

# %%
import seaborn as sns

# %%
plt.plot(x, np.sin(x), 'b--')
plt.plot(x, np.cos(x), 'r--')
plt.show()

# %%
# para usar o seaborn é só importar ele e já esta utilizando-o em default, agora para 
# setar seus valores é só setalos kkkkk simples não, segue o exemplo abaixo.
sns.set_style('dark')

# %%
plt.plot(x, np.sin(x), 'b--')
plt.plot(x, np.cos(x), 'r--')
plt.show()

# %%
sns.barplot
plt.plot(x, np.sin(x), 'b--')
plt.plot(x, np.cos(x), 'r--')
plt.show()
