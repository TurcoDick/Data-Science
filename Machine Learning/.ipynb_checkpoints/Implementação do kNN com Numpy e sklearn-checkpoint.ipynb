# %%
'''
https://archive.ics.uci.edu/ml/datasets/Balance+Scale
    
Attribute Information:

1. Class Name: 3 (L, B, R) 
2. Left-Weight: 5 (1, 2, 3, 4, 5) 
3. Left-Distance: 5 (1, 2, 3, 4, 5) 
4. Right-Weight: 5 (1, 2, 3, 4, 5) 
5. Right-Distance: 5 (1, 2, 3, 4, 5)
    
São 625 exemplos, 4 atributos e 3 possíveis classes.
Onde tem "L" coloquei 1, onde tem "B" coloquei 2 e onde tem "R" coloquei 3.

'''
# Out:
# '\nhttps://archive.ics.uci.edu/ml/datasets/Balance+Scale\n    \nAttribute Information:\n\n1. Class Name: 3 (L, B, R) \n2. Left-Weight: 5 (1, 2, 3, 4, 5) \n3. Left-Distance: 5 (1, 2, 3, 4, 5) \n4. Right-Weight: 5 (1, 2, 3, 4, 5) \n5. Right-Distance: 5 (1, 2, 3, 4, 5)\n    \nSão 625 exemplos, 4 atributos e 3 possíveis classes.\nOnde tem "L" coloquei 1, onde tem "B" coloquei 2 e onde tem "R" coloquei 3.\n\n'

# %%
# o anunciado de cima é de um arquivo que vou modifica-lo agora
with open('/home/alison/Projetos/Data Science/DataSets/balance-scale.data.txt','r') as f:
    arq = open('/home/alison/Projetos/Data Science/DataSets/balance-scale.data.modificado.txt','a')
    for linha in f.readlines():    
        arq.write(linha.replace('L' , '1'))
        arq.write(linha.replace('B' , '2'))
        arq.write(linha.replace('R' , '3'))
                  
    arq.close()
# Out:
#   File "<ipython-input-19-781f83f88681>", line 6
#     arq.write(linha.replace('B' , '2')
#       ^
# SyntaxError: invalid syntax

# %%
with open('/home/alison/Projetos/Data Science/DataSets/balance-scale.data.modificado.txt','r') as f:
    for linha in f.readlines():
        print(linha)
# Out:
# B,1,1,1,1
#
# 3,1,1,1,2
#
# 3,1,1,1,3
#
# 3,1,1,1,4
#
# 3,1,1,1,5
#
# 3,1,1,2,1
#
# 3,1,1,2,2
#
# 3,1,1,2,3
#
# 3,1,1,2,4
#
# 3,1,1,2,5
#
# 3,1,1,3,1
#
# 3,1,1,3,2
#
# 3,1,1,3,3
#
# 3,1,1,3,4
#
# 3,1,1,3,5
#
# 3,1,1,4,1
#
# 3,1,1,4,2
#
# 3,1,1,4,3
#
# 3,1,1,4,4
#
# 3,1,1,4,5
#
# 3,1,1,5,1
#
# 3,1,1,5,2
#
# 3,1,1,5,3
#
# 3,1,1,5,4
#
# 3,1,1,5,5
#
# L,1,2,1,1
#
# B,1,2,1,2
#
# 3,1,2,1,3
#
# 3,1,2,1,4
#
# 3,1,2,1,5
#
# B,1,2,2,1
#
# 3,1,2,2,2
#
# 3,1,2,2,3
#
# 3,1,2,2,4
#
# 3,1,2,2,5
#
# 3,1,2,3,1
#
# 3,1,2,3,2
#
# 3,1,2,3,3
#
# 3,1,2,3,4
#
# 3,1,2,3,5
#
# 3,1,2,4,1
#
# 3,1,2,4,2
#
# 3,1,2,4,3
#
# 3,1,2,4,4
#
# 3,1,2,4,5
#
# 3,1,2,5,1
#
# 3,1,2,5,2
#
# 3,1,2,5,3
#
# 3,1,2,5,4
#
# 3,1,2,5,5
#
# L,1,3,1,1
#
# L,1,3,1,2
#
# B,1,3,1,3
#
# 3,1,3,1,4
#
# 3,1,3,1,5
#
# L,1,3,2,1
#
# 3,1,3,2,2
#
# 3,1,3,2,3
#
# 3,1,3,2,4
#
# 3,1,3,2,5
#
# B,1,3,3,1
#
# 3,1,3,3,2
#
# 3,1,3,3,3
#
# 3,1,3,3,4
#
# 3,1,3,3,5
#
# 3,1,3,4,1
#
# 3,1,3,4,2
#
# 3,1,3,4,3
#
# 3,1,3,4,4
#
# 3,1,3,4,5
#
# 3,1,3,5,1
#
# ...
